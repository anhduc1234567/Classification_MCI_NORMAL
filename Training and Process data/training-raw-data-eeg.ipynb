# %%
import os
from glob import glob
import mne
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, roc_auc_score, f1_score, roc_curve
import matplotlib.pyplot as plt
import seaborn as sns
from mne.preprocessing import ICA
# Set random seed for reproducibility
torch.manual_seed(42)
np.random.seed(42)
plt.rcParams['figure.figsize'] = [8, 6]

# Check for GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

# Data loading
all_files_path = glob('/kaggle/input/datanew/newdata2/*.edf')
print(f"Number of EDF files: {len(all_files_path)}")

# Load labels from Excel files
file_path = '/kaggle/input/datanew/newdata2/states(1).xlsx'
df_labels = pd.read_excel(file_path)
labels1 = df_labels['status'].tolist()

file_path2 = '/kaggle/input/datanew/newdata2/States.xlsx'
df_labels2 = pd.read_excel(file_path2)
labels2 = df_labels2['status'].tolist()

labels = labels1 + labels2
labels = [0 if label == 'NORMAL' else 1 for label in labels]

# Separate healthy and patient files
healthy_file_path = [p for p in all_files_path if labels[int(os.path.basename(p).split('.')[0]) - 1] == 0]
patient_file_path = [p for p in all_files_path if labels[int(os.path.basename(p).split('.')[0]) - 1] == 1]
print(f"Healthy files: {len(healthy_file_path)}, Patient files: {len(patient_file_path)}")

# Create test set with 5 patients from each group
test_file_path = healthy_file_path[-5:] + patient_file_path[-5:]
healthy_file_path = healthy_file_path[:-5]
patient_file_path = patient_file_path[:-5]
print(f"Test files: {len(test_file_path)}, Updated Healthy files: {len(healthy_file_path)}, Updated Patient files: {len(patient_file_path)}")

# Create test labels
test_labels = [0] * 5 + [1] * 5  # 5 healthy (0) + 5 patient (1)

# %%
def ica_filter(raw):
    data = raw.get_data()
    data = (data - data.mean(axis=1, keepdims=True)) / data.std(axis=1, keepdims=True)
    raw._data = data

    # Fit ICA
    ica = ICA(n_components=15, random_state=42, max_iter=800)
    ica.fit(raw)

    # Kiểm tra và đặt kênh EOG
    eog_channels = [ch for ch in raw.ch_names if 'EOG' in ch.upper()]
    if not eog_channels:
        print("Không tìm thấy kênh EOG, dùng Fp1 và Fp2 làm kênh EOG thay thế...")
        raw.set_channel_types({'Fp1': 'eog', 'Fp2': 'eog'})
        eog_indices, eog_scores = ica.find_bads_eog(raw, ch_name=['Fp1', 'Fp2'])
        raw.set_channel_types({'Fp1': 'eeg', 'Fp2': 'eeg'})  # Đặt lại
    else:
        eog_indices, eog_scores = ica.find_bads_eog(raw)

    # Gán thành phần nhiễu
    ica.exclude = eog_indices
    print(f'Thành phần nháy mắt: {eog_indices}')

    # Áp dụng ICA
    raw_clean = ica.apply(raw.copy())
    raw._data = raw_clean.get_data()
    return raw

# %%
def read_data(file_path):
    datax = mne.io.read_raw_edf(file_path, preload=True)
    datax.set_eeg_reference()
    datax.filter(l_freq=1, h_freq=40)
    datax = ica_filter(datax)
    epochs = mne.make_fixed_length_epochs(datax, duration=25, overlap=0)
    epochs = epochs.get_data()
    return epochs  # Shape: (trials, channels, length)

# Load and preprocess train/validation data
control_epochs_array = [read_data(subject) for subject in healthy_file_path]
patient_epochs_array = [read_data(subject) for subject in patient_file_path]

# Create labels and group arrays for train/validation
control_epochs_labels = [np.zeros(len(epochs)) for epochs in control_epochs_array]
patient_epochs_labels = [np.ones(len(epochs)) for epochs in patient_epochs_array]
data_array = np.vstack(control_epochs_array + patient_epochs_array)
label_array = np.hstack(control_epochs_labels + patient_epochs_labels)
group_array = np.hstack([np.ones(len(epochs)) * i for i, epochs in enumerate(control_epochs_array + patient_epochs_array)])

# Load and preprocess test data
test_epochs_array = [read_data(subject) for subject in test_file_path]
test_epochs_labels = [np.zeros(len(epochs)) if test_labels[i] == 0 else np.ones(len(epochs)) for i, epochs in enumerate(test_epochs_array)]
test_data_array = np.vstack(test_epochs_array)
test_label_array = np.hstack(test_epochs_labels)
# Out:
# Extracting EDF parameters from /kaggle/input/datanew/newdata2/19.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 465663  =      0.000 ...  1818.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Fitting ICA to data using 19 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.2s finished
# Selecting by number: 15 components
# Fitting ICA took 4.7s.
# Không tìm thấy kênh EOG, dùng Fp1 và Fp2 làm kênh EOG thay thế...
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# Thành phần nháy mắt: [8]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 19 PCA components
# Not setting metadata
# 72 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 72 events and 6400 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /kaggle/input/datanew/newdata2/52.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 473087  =      0.000 ...  1847.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Fitting ICA to data using 19 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.2s finished
# Selecting by number: 15 components
# Fitting ICA took 4.2s.
# Không tìm thấy kênh EOG, dùng Fp1 và Fp2 làm kênh EOG thay thế...
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# Thành phần nháy mắt: []
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 0 ICA components
#     Projecting back using 19 PCA components
# Not setting metadata
# 73 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 73 events and 6400 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /kaggle/input/datanew/newdata2/13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 476159  =      0.000 ...  1859.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Fitting ICA to data using 19 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.2s finished
# Selecting by number: 15 components
# Fitting ICA took 4.1s.
# Không tìm thấy kênh EOG, dùng Fp1 và Fp2 làm kênh EOG thay thế...
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# Thành phần nháy mắt: [0]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 19 PCA components
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 6400 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /kaggle/input/datanew/newdata2/21.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 462335  =      0.000 ...  1805.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Fitting ICA to data using 19 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.3s finished
# Selecting by number: 15 components
# Fitting ICA took 2.1s.
# Không tìm thấy kênh EOG, dùng Fp1 và Fp2 làm kênh EOG thay thế...
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# Thành phần nháy mắt: [0]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 19 PCA components
# Not setting metadata
# 72 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 72 events and 6400 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /kaggle/input/datanew/newdata2/31.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 462591  =      0.000 ...  1806.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Fitting ICA to data using 19 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.2s finished
# Selecting by number: 15 components
# Fitting ICA took 4.0s.
# Không tìm thấy kênh EOG, dùng Fp1 và Fp2 làm kênh EOG thay thế...
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# Thành phần nháy mắt: [10, 9]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 2 ICA components
#     Projecting back using 19 PCA components
# Not setting metadata
# 72 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 72 events and 6400 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /kaggle/input/datanew/newdata2/36.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 461311  =      0.000 ...  1801.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Fitting ICA to data using 19 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.2s finished
# Selecting by number: 15 components
# Fitting ICA took 2.4s.
# Không tìm thấy kênh EOG, dùng Fp1 và Fp2 làm kênh EOG thay thế...
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# Thành phần nháy mắt: [3]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 19 PCA components
# Not setting metadata
# 72 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 72 events and 6400 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /kaggle/input/datanew/newdata2/44.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 463359  =      0.000 ...  1809.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Fitting ICA to data using 19 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.2s finished
# Selecting by number: 15 components
# Fitting ICA took 4.1s.
# Không tìm thấy kênh EOG, dùng Fp1 và Fp2 làm kênh EOG thay thế...
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# Thành phần nháy mắt: []
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 0 ICA components
#     Projecting back using 19 PCA components
# Not setting metadata
# 72 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 72 events and 6400 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /kaggle/input/datanew/newdata2/56.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 466175  =      0.000 ...  1820.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Fitting ICA to data using 19 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.2s finished
# Selecting by number: 15 components
# Fitting ICA took 6.2s.
# Không tìm thấy kênh EOG, dùng Fp1 và Fp2 làm kênh EOG thay thế...
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# Thành phần nháy mắt: []
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 0 ICA components
#     Projecting back using 19 PCA components
# Not setting metadata
# 72 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 72 events and 6400 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /kaggle/input/datanew/newdata2/24.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 463615  =      0.000 ...  1810.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Fitting ICA to data using 19 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.2s finished
# Selecting by number: 15 components
# Fitting ICA took 2.4s.
# Không tìm thấy kênh EOG, dùng Fp1 và Fp2 làm kênh EOG thay thế...
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# Thành phần nháy mắt: [0]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 19 PCA components
# Not setting metadata
# 72 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 72 events and 6400 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /kaggle/input/datanew/newdata2/30.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 463359  =      0.000 ...  1809.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Fitting ICA to data using 19 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.2s finished
# Selecting by number: 15 components
# Fitting ICA took 4.4s.
# Không tìm thấy kênh EOG, dùng Fp1 và Fp2 làm kênh EOG thay thế...
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# Thành phần nháy mắt: [10, 6, 0]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 3 ICA components
#     Projecting back using 19 PCA components
# Not setting metadata
# 72 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 72 events and 6400 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /kaggle/input/datanew/newdata2/10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 461567  =      0.000 ...  1802.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Fitting ICA to data using 19 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.2s finished
# Selecting by number: 15 components
# Fitting ICA took 2.7s.
# Không tìm thấy kênh EOG, dùng Fp1 và Fp2 làm kênh EOG thay thế...
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# Thành phần nháy mắt: [1]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 19 PCA components
# Not setting metadata
# 72 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 72 events and 6400 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /kaggle/input/datanew/newdata2/26.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 464127  =      0.000 ...  1812.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Fitting ICA to data using 19 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.2s finished
# Selecting by number: 15 components
# Fitting ICA took 1.8s.
# Không tìm thấy kênh EOG, dùng Fp1 và Fp2 làm kênh EOG thay thế...
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# Thành phần nháy mắt: [1]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 19 PCA components
# Not setting metadata
# 72 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 72 events and 6400 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /kaggle/input/datanew/newdata2/34.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 534783  =      0.000 ...  2088.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# ...
# Not setting metadata
# 72 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 72 events and 6400 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /kaggle/input/datanew/newdata2/6.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 477183  =      0.000 ...  1863.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Fitting ICA to data using 19 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.3s finished
# Selecting by number: 15 components
# Fitting ICA took 2.8s.
# Không tìm thấy kênh EOG, dùng Fp1 và Fp2 làm kênh EOG thay thế...
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# Thành phần nháy mắt: [6]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 19 PCA components
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 6400 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /kaggle/input/datanew/newdata2/58.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 467455  =      0.000 ...  1825.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Fitting ICA to data using 19 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.2s finished
# Selecting by number: 15 components
# Fitting ICA took 2.9s.
# Không tìm thấy kênh EOG, dùng Fp1 và Fp2 làm kênh EOG thay thế...
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# Thành phần nháy mắt: []
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 0 ICA components
#     Projecting back using 19 PCA components
# Not setting metadata
# 73 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 73 events and 6400 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /kaggle/input/datanew/newdata2/11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 476671  =      0.000 ...  1861.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Fitting ICA to data using 19 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.3s finished
# Selecting by number: 15 components
# Fitting ICA took 4.9s.
# Không tìm thấy kênh EOG, dùng Fp1 và Fp2 làm kênh EOG thay thế...
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# Thành phần nháy mắt: [1]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 19 PCA components
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 6400 original time points ...
# 0 bad epochs dropped
# Extracting EDF parameters from /kaggle/input/datanew/newdata2/54.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 486911  =      0.000 ...  1901.996 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Fitting ICA to data using 19 channels (please be patient, this may take a while)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.3s finished
# Selecting by number: 15 components
# Fitting ICA took 3.6s.
# Không tìm thấy kênh EOG, dùng Fp1 và Fp2 làm kênh EOG thay thế...
# Using EOG channels: Fp1, Fp2
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2560 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# Thành phần nháy mắt: [0]
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 1 ICA component
#     Projecting back using 19 PCA components
# Not setting metadata
# 76 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 76 events and 6400 original time points ...
# 0 bad epochs dropped

# %%
class CNNModel(nn.Module):
    def __init__(self, input_shape):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=input_shape[1], out_channels=19, kernel_size=7, stride=1, padding='valid')
        self.bn1 = nn.BatchNorm1d(5)
        self.leaky_relu1 = nn.LeakyReLU(0.3)
        self.maxpool1 = nn.MaxPool1d(kernel_size=2, stride=2)
        
        self.conv2 = nn.Conv1d(19, 19, kernel_size=3, stride=1, padding='valid')
        self.leaky_relu2 = nn.LeakyReLU(0.3)
        self.maxpool2 = nn.MaxPool1d(kernel_size=2, stride=2)
        
        self.dropout1 = nn.Dropout(0.5)
        self.conv3 = nn.Conv1d(19, 19, kernel_size=3, stride=1, padding='valid')
        self.leaky_relu3 = nn.LeakyReLU(0.3)
        self.avgpool1 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.dropout2 = nn.Dropout(0.5)
        self.conv4 = nn.Conv1d(19, 5, kernel_size=3, stride=1, padding='valid')
        self.leaky_relu4 = nn.LeakyReLU(0.3)
        self.avgpool2 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.conv5 = nn.Conv1d(5, 5, kernel_size=3, stride=1, padding='valid')
        self.leaky_relu5 = nn.LeakyReLU(0.3)
        self.global_avgpool = nn.AdaptiveAvgPool1d(1)
        
        self.fc = nn.Linear(5, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.leaky_relu1(x)
        x = self.maxpool1(x)
        
        x = self.conv2(x)
        x = self.leaky_relu2(x)
        x = self.maxpool2(x)
        
        x = self.dropout1(x)
        x = self.conv3(x)
        x = self.leaky_relu3(x)
        x = self.avgpool1(x)
        
        x = self.dropout2(x)
        x = self.conv4(x)
        x = self.leaky_relu4(x)
        x = self.avgpool2(x)
        
        x = self.conv5(x)
        x = self.leaky_relu5(x)
        x = self.global_avgpool(x)
        
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        x = self.sigmoid(x)
        return x

# %%
### accuracy = []
best_val_accuracy = 0.0
best_model_path = "best_model.pth"
best_model_fold = 0
gkf = GroupKFold(n_splits=5)
accuracy = []
# Train/validation loop
for fold, (train_index, val_index) in enumerate(gkf.split(data_array, label_array, groups=group_array)):
    print(f"\nFold {fold + 1}")
    train_features, train_labels = data_array[train_index], label_array[train_index]
    val_features, val_labels = data_array[val_index], label_array[val_index]

    # Standardize data
    scaler = StandardScaler()
    train_features = scaler.fit_transform(train_features.reshape(-1, train_features.shape[-1])).reshape(train_features.shape)
    val_features = scaler.transform(val_features.reshape(-1, val_features.shape[-1])).reshape(val_features.shape)

    # Convert to PyTorch tensors
    train_features = torch.tensor(train_features, dtype=torch.float32).to(device)
    train_labels = torch.tensor(train_labels, dtype=torch.float32).unsqueeze(1).to(device)
    val_features = torch.tensor(val_features, dtype=torch.float32).to(device)
    val_labels = torch.tensor(val_labels, dtype=torch.float32).unsqueeze(1).to(device)

    # Create DataLoader
    train_dataset = TensorDataset(train_features, train_labels)
    val_dataset = TensorDataset(val_features, val_labels)
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

    # Initialize model, loss, and optimizer
    model = CNNModel(input_shape=train_features.shape).to(device)
    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), lr=0.0001)

    # Training loop
    epochs = 30
    best_fold_val_accuracy = 0.0
    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0
        for inputs, labels in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            predicted = (outputs >= 0.5).float()
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        train_accuracy = correct / total
        print(f"Epoch {epoch+1}/{epochs}, Loss: {running_loss/len(train_loader):.4f}, Accuracy: {train_accuracy:.4f}")

        # Validation
        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                predicted = (outputs >= 0.5).float()
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        val_accuracy = correct / total
        print(f"Validation Loss: {val_loss/len(val_loader):.4f}, Validation Accuracy: {val_accuracy:.4f}")

        # Save best model for this fold
        if val_accuracy > best_fold_val_accuracy:
            best_fold_val_accuracy = val_accuracy
            torch.save(model.state_dict(), f"best_model_fold_{fold}.pth")
            print(f"Saved best model for fold {fold + 1} with validation accuracy: {val_accuracy:.4f}")
    torch.save(model.state_dict(), f"model_fold_{fold}.pth")
            

    accuracy.append(best_fold_val_accuracy)

    # Update global best model
    if best_fold_val_accuracy > best_val_accuracy:
        best_val_accuracy = best_fold_val_accuracy
        best_model_path = f"best_model_fold_{fold}_new.pth"
        best_model_fold = fold + 1

print(f"Average Validation Accuracy: {np.mean(accuracy):.4f}")
print(f"Best model from fold {best_model_fold} with validation accuracy: {best_val_accuracy:.4f}")
# Out:
# Fold 1
# Epoch 1/30, Loss: 0.7008, Accuracy: 0.4193
# Validation Loss: 0.6760, Validation Accuracy: 0.7078
# Saved best model for fold 1 with validation accuracy: 0.7078
# Epoch 2/30, Loss: 0.6944, Accuracy: 0.4542
# Validation Loss: 0.6851, Validation Accuracy: 0.8123
# Saved best model for fold 1 with validation accuracy: 0.8123
# Epoch 3/30, Loss: 0.6839, Accuracy: 0.6089
# Validation Loss: 0.7042, Validation Accuracy: 0.2949
# Epoch 4/30, Loss: 0.6704, Accuracy: 0.5807
# Validation Loss: 0.7343, Validation Accuracy: 0.2922
# Epoch 5/30, Loss: 0.6593, Accuracy: 0.5807
# Validation Loss: 0.7624, Validation Accuracy: 0.2922
# Epoch 6/30, Loss: 0.6569, Accuracy: 0.5807
# Validation Loss: 0.7787, Validation Accuracy: 0.2922
# Epoch 7/30, Loss: 0.6571, Accuracy: 0.5807
# Validation Loss: 0.7867, Validation Accuracy: 0.2922
# Epoch 8/30, Loss: 0.6491, Accuracy: 0.5807
# Validation Loss: 0.7842, Validation Accuracy: 0.2922
# Epoch 9/30, Loss: 0.6494, Accuracy: 0.5807
# Validation Loss: 0.8065, Validation Accuracy: 0.2922
# Epoch 10/30, Loss: 0.6432, Accuracy: 0.5807
# Validation Loss: 0.7956, Validation Accuracy: 0.2922
# Epoch 11/30, Loss: 0.6421, Accuracy: 0.5807
# Validation Loss: 0.7916, Validation Accuracy: 0.2922
# Epoch 12/30, Loss: 0.6391, Accuracy: 0.5807
# Validation Loss: 0.7986, Validation Accuracy: 0.2922
# Epoch 13/30, Loss: 0.6344, Accuracy: 0.5807
# Validation Loss: 0.8127, Validation Accuracy: 0.2922
# Epoch 14/30, Loss: 0.6334, Accuracy: 0.5817
# Validation Loss: 0.8019, Validation Accuracy: 0.2976
# Epoch 15/30, Loss: 0.6297, Accuracy: 0.5826
# Validation Loss: 0.8102, Validation Accuracy: 0.3070
# Epoch 16/30, Loss: 0.6252, Accuracy: 0.5846
# Validation Loss: 0.8122, Validation Accuracy: 0.3217
# Epoch 17/30, Loss: 0.6249, Accuracy: 0.5899
# Validation Loss: 0.8202, Validation Accuracy: 0.3298
# Epoch 18/30, Loss: 0.6202, Accuracy: 0.5991
# Validation Loss: 0.8356, Validation Accuracy: 0.3324
# Epoch 19/30, Loss: 0.6179, Accuracy: 0.6096
# Validation Loss: 0.8359, Validation Accuracy: 0.3552
# Epoch 20/30, Loss: 0.6179, Accuracy: 0.6185
# Validation Loss: 0.8049, Validation Accuracy: 0.4169
# Epoch 21/30, Loss: 0.6126, Accuracy: 0.6280
# Validation Loss: 0.8035, Validation Accuracy: 0.4531
# Epoch 22/30, Loss: 0.6123, Accuracy: 0.6283
# Validation Loss: 0.7934, Validation Accuracy: 0.4920
# Epoch 23/30, Loss: 0.6080, Accuracy: 0.6441
# Validation Loss: 0.8107, Validation Accuracy: 0.4826
# Epoch 24/30, Loss: 0.6023, Accuracy: 0.6576
# Validation Loss: 0.8318, Validation Accuracy: 0.4826
# Epoch 25/30, Loss: 0.6011, Accuracy: 0.6674
# Validation Loss: 0.8289, Validation Accuracy: 0.5013
# Epoch 26/30, Loss: 0.5983, Accuracy: 0.6655
# Validation Loss: 0.8021, Validation Accuracy: 0.5147
# Epoch 27/30, Loss: 0.5953, Accuracy: 0.6858
# Validation Loss: 0.8404, Validation Accuracy: 0.5107
# Epoch 28/30, Loss: 0.5932, Accuracy: 0.6944
# Validation Loss: 0.8073, Validation Accuracy: 0.5201
# Epoch 29/30, Loss: 0.5884, Accuracy: 0.7069
# Validation Loss: 0.7718, Validation Accuracy: 0.5509
# Epoch 30/30, Loss: 0.5843, Accuracy: 0.7125
# Validation Loss: 0.8130, Validation Accuracy: 0.5241
#
# Fold 2
# Epoch 1/30, Loss: 0.6874, Accuracy: 0.5562
# Validation Loss: 0.7111, Validation Accuracy: 0.3919
# Saved best model for fold 2 with validation accuracy: 0.3919
# Epoch 2/30, Loss: 0.6860, Accuracy: 0.5562
# Validation Loss: 0.7145, Validation Accuracy: 0.3919
# Epoch 3/30, Loss: 0.6848, Accuracy: 0.5562
# Validation Loss: 0.7177, Validation Accuracy: 0.3919
# Epoch 4/30, Loss: 0.6818, Accuracy: 0.5562
# Validation Loss: 0.7207, Validation Accuracy: 0.3919
# Epoch 5/30, Loss: 0.6792, Accuracy: 0.5562
# Validation Loss: 0.7264, Validation Accuracy: 0.3919
# Epoch 6/30, Loss: 0.6760, Accuracy: 0.5562
# Validation Loss: 0.7303, Validation Accuracy: 0.3919
# Epoch 7/30, Loss: 0.6731, Accuracy: 0.5562
# Validation Loss: 0.7388, Validation Accuracy: 0.3919
# Epoch 8/30, Loss: 0.6686, Accuracy: 0.5562
# Validation Loss: 0.7427, Validation Accuracy: 0.3919
# Epoch 9/30, Loss: 0.6620, Accuracy: 0.5562
# Validation Loss: 0.7483, Validation Accuracy: 0.3919
# Epoch 10/30, Loss: 0.6550, Accuracy: 0.5562
# Validation Loss: 0.7562, Validation Accuracy: 0.3919
# Epoch 11/30, Loss: 0.6511, Accuracy: 0.5572
# Validation Loss: 0.7684, Validation Accuracy: 0.3919
# Epoch 12/30, Loss: 0.6395, Accuracy: 0.5772
# Validation Loss: 0.7607, Validation Accuracy: 0.4430
# Saved best model for fold 2 with validation accuracy: 0.4430
# Epoch 13/30, Loss: 0.6305, Accuracy: 0.6081
# Validation Loss: 0.7718, Validation Accuracy: 0.5020
# Saved best model for fold 2 with validation accuracy: 0.5020
# Epoch 14/30, Loss: 0.6231, Accuracy: 0.6406
# Validation Loss: 0.7708, Validation Accuracy: 0.5718
# Saved best model for fold 2 with validation accuracy: 0.5718
# Epoch 15/30, Loss: 0.6082, Accuracy: 0.6912
# Validation Loss: 0.7437, Validation Accuracy: 0.6013
# Saved best model for fold 2 with validation accuracy: 0.6013
# Epoch 16/30, Loss: 0.5916, Accuracy: 0.7355
# Validation Loss: 0.7638, Validation Accuracy: 0.6000
# Epoch 17/30, Loss: 0.5778, Accuracy: 0.7484
# Validation Loss: 0.7774, Validation Accuracy: 0.5987
# Epoch 18/30, Loss: 0.5574, Accuracy: 0.7671
# Validation Loss: 0.7719, Validation Accuracy: 0.5893
# Epoch 19/30, Loss: 0.5336, Accuracy: 0.7691
# Validation Loss: 0.7654, Validation Accuracy: 0.5906
# Epoch 20/30, Loss: 0.5117, Accuracy: 0.7937
# Validation Loss: 0.7338, Validation Accuracy: 0.5893
# Epoch 21/30, Loss: 0.4930, Accuracy: 0.7996
# Validation Loss: 0.7856, Validation Accuracy: 0.5973
# Epoch 22/30, Loss: 0.4800, Accuracy: 0.7993
# Validation Loss: 0.7629, Validation Accuracy: 0.6107
# Saved best model for fold 2 with validation accuracy: 0.6107
# Epoch 23/30, Loss: 0.4563, Accuracy: 0.8167
# Validation Loss: 0.7712, Validation Accuracy: 0.6107
# Epoch 24/30, Loss: 0.4399, Accuracy: 0.8262
# Validation Loss: 0.7264, Validation Accuracy: 0.6376
# Saved best model for fold 2 with validation accuracy: 0.6376
# Epoch 25/30, Loss: 0.4227, Accuracy: 0.8279
# Validation Loss: 0.7848, Validation Accuracy: 0.6268
# Epoch 26/30, Loss: 0.4140, Accuracy: 0.8351
# Validation Loss: 0.7366, Validation Accuracy: 0.6443
# Saved best model for fold 2 with validation accuracy: 0.6443
# Epoch 27/30, Loss: 0.4011, Accuracy: 0.8535
# Validation Loss: 0.7105, Validation Accuracy: 0.6711
# Saved best model for fold 2 with validation accuracy: 0.6711
# Epoch 28/30, Loss: 0.3819, Accuracy: 0.8558
# Validation Loss: 0.7065, Validation Accuracy: 0.6819
# Saved best model for fold 2 with validation accuracy: 0.6819
# Epoch 29/30, Loss: 0.3750, Accuracy: 0.8499
# Validation Loss: 0.7426, Validation Accuracy: 0.6805
# Epoch 30/30, Loss: 0.3605, Accuracy: 0.8604
# Validation Loss: 0.7745, Validation Accuracy: 0.6792
#
# Fold 3
# Epoch 1/30, Loss: 0.7018, Accuracy: 0.5082
# Validation Loss: 0.6833, Validation Accuracy: 0.5879
# Saved best model for fold 3 with validation accuracy: 0.5879
# Epoch 2/30, Loss: 0.6997, Accuracy: 0.5082
# Validation Loss: 0.6833, Validation Accuracy: 0.5879
# Epoch 3/30, Loss: 0.6992, Accuracy: 0.5082
# Validation Loss: 0.6835, Validation Accuracy: 0.5879
# Epoch 4/30, Loss: 0.6985, Accuracy: 0.5082
# Validation Loss: 0.6837, Validation Accuracy: 0.5879
# Epoch 5/30, Loss: 0.6968, Accuracy: 0.5082
# Validation Loss: 0.6844, Validation Accuracy: 0.5879
# Epoch 6/30, Loss: 0.6934, Accuracy: 0.5112
# Validation Loss: 0.6856, Validation Accuracy: 0.5866
# Epoch 7/30, Loss: 0.6884, Accuracy: 0.5470
# Validation Loss: 0.6897, Validation Accuracy: 0.5866
# Epoch 8/30, Loss: 0.6838, Accuracy: 0.5821
# Validation Loss: 0.6930, Validation Accuracy: 0.5893
# Saved best model for fold 3 with validation accuracy: 0.5893
# Epoch 9/30, Loss: 0.6782, Accuracy: 0.5831
# Validation Loss: 0.6966, Validation Accuracy: 0.5597
# Epoch 10/30, Loss: 0.6756, Accuracy: 0.5309
# Validation Loss: 0.7000, Validation Accuracy: 0.4644
# Epoch 11/30, Loss: 0.6732, Accuracy: 0.5342
# Validation Loss: 0.7014, Validation Accuracy: 0.4255
# Epoch 12/30, Loss: 0.6686, Accuracy: 0.5375
# Validation Loss: 0.7014, Validation Accuracy: 0.4537
# Epoch 13/30, Loss: 0.6662, Accuracy: 0.5654
# Validation Loss: 0.7043, Validation Accuracy: 0.4215
# Epoch 14/30, Loss: 0.6624, Accuracy: 0.5535
# Validation Loss: 0.7015, Validation Accuracy: 0.5248
# Epoch 15/30, Loss: 0.6614, Accuracy: 0.5516
# Validation Loss: 0.7045, Validation Accuracy: 0.4564
# Epoch 16/30, Loss: 0.6557, Accuracy: 0.5871
# Validation Loss: 0.6978, Validation Accuracy: 0.6040
# Saved best model for fold 3 with validation accuracy: 0.6040
# Epoch 17/30, Loss: 0.6512, Accuracy: 0.6048
# Validation Loss: 0.7023, Validation Accuracy: 0.5396
# Epoch 18/30, Loss: 0.6455, Accuracy: 0.6101
# Validation Loss: 0.7013, Validation Accuracy: 0.5651
# Epoch 19/30, Loss: 0.6383, Accuracy: 0.6179
# Validation Loss: 0.7002, Validation Accuracy: 0.5758
# Epoch 20/30, Loss: 0.6327, Accuracy: 0.6413
# Validation Loss: 0.6965, Validation Accuracy: 0.6148
# Saved best model for fold 3 with validation accuracy: 0.6148
# Epoch 21/30, Loss: 0.6254, Accuracy: 0.6560
# Validation Loss: 0.6980, Validation Accuracy: 0.6027
# Epoch 22/30, Loss: 0.6216, Accuracy: 0.6649
# Validation Loss: 0.6953, Validation Accuracy: 0.6148
# Epoch 23/30, Loss: 0.6056, Accuracy: 0.6902
# Validation Loss: 0.6954, Validation Accuracy: 0.6336
# Saved best model for fold 3 with validation accuracy: 0.6336
# Epoch 24/30, Loss: 0.5902, Accuracy: 0.6961
# Validation Loss: 0.6957, Validation Accuracy: 0.6268
# Epoch 25/30, Loss: 0.5723, Accuracy: 0.7093
# Validation Loss: 0.7051, Validation Accuracy: 0.6121
# Epoch 26/30, Loss: 0.5522, Accuracy: 0.7188
# Validation Loss: 0.7240, Validation Accuracy: 0.6188
# Epoch 27/30, Loss: 0.5297, Accuracy: 0.7306
# Validation Loss: 0.7333, Validation Accuracy: 0.5919
# Epoch 28/30, Loss: 0.5021, Accuracy: 0.7477
# Validation Loss: 0.7473, Validation Accuracy: 0.6094
# Epoch 29/30, Loss: 0.4799, Accuracy: 0.7608
# Validation Loss: 0.7699, Validation Accuracy: 0.5906
# Epoch 30/30, Loss: 0.4556, Accuracy: 0.7786
# Validation Loss: 0.7878, Validation Accuracy: 0.5973
#
# Fold 4
# Epoch 1/30, Loss: 0.6931, Accuracy: 0.5064
# Validation Loss: 0.6945, Validation Accuracy: 0.3646
# Saved best model for fold 4 with validation accuracy: 0.3646
# Epoch 2/30, Loss: 0.6929, Accuracy: 0.5064
# Validation Loss: 0.6946, Validation Accuracy: 0.3646
# Epoch 3/30, Loss: 0.6928, Accuracy: 0.5064
# Validation Loss: 0.6947, Validation Accuracy: 0.3646
# Epoch 4/30, Loss: 0.6925, Accuracy: 0.5064
# Validation Loss: 0.6947, Validation Accuracy: 0.3646
# Epoch 5/30, Loss: 0.6921, Accuracy: 0.5064
# Validation Loss: 0.6950, Validation Accuracy: 0.3646
# Epoch 6/30, Loss: 0.6912, Accuracy: 0.5064
# Validation Loss: 0.6951, Validation Accuracy: 0.3646
# Epoch 7/30, Loss: 0.6891, Accuracy: 0.5114
# Validation Loss: 0.6942, Validation Accuracy: 0.4425
# Saved best model for fold 4 with validation accuracy: 0.4425
# Epoch 8/30, Loss: 0.6844, Accuracy: 0.5195
# Validation Loss: 0.6945, Validation Accuracy: 0.5352
# Saved best model for fold 4 with validation accuracy: 0.5352
# Epoch 9/30, Loss: 0.6733, Accuracy: 0.6158
# Validation Loss: 0.6883, Validation Accuracy: 0.4042
# Epoch 10/30, Loss: 0.6504, Accuracy: 0.6698
# Validation Loss: 0.6809, Validation Accuracy: 0.4598
# Epoch 11/30, Loss: 0.6139, Accuracy: 0.7111
# Validation Loss: 0.6661, Validation Accuracy: 0.4994
# Epoch 12/30, Loss: 0.5660, Accuracy: 0.7436
# Validation Loss: 0.6575, Validation Accuracy: 0.5229
# Epoch 13/30, Loss: 0.5125, Accuracy: 0.7805
# Validation Loss: 0.6591, Validation Accuracy: 0.6106
# Saved best model for fold 4 with validation accuracy: 0.6106
# Epoch 14/30, Loss: 0.4709, Accuracy: 0.7903
# Validation Loss: 0.6934, Validation Accuracy: 0.5698
# Epoch 15/30, Loss: 0.4399, Accuracy: 0.8117
# Validation Loss: 0.6908, Validation Accuracy: 0.5735
# Epoch 16/30, Loss: 0.4039, Accuracy: 0.8275
# Validation Loss: 0.7120, Validation Accuracy: 0.6156
# Saved best model for fold 4 with validation accuracy: 0.6156
# Epoch 17/30, Loss: 0.3895, Accuracy: 0.8326
# Validation Loss: 0.7803, Validation Accuracy: 0.6156
# Epoch 18/30, Loss: 0.3662, Accuracy: 0.8477
# Validation Loss: 0.7805, Validation Accuracy: 0.5921
# Epoch 19/30, Loss: 0.3531, Accuracy: 0.8480
# Validation Loss: 0.8469, Validation Accuracy: 0.6255
# Saved best model for fold 4 with validation accuracy: 0.6255
# Epoch 20/30, Loss: 0.3462, Accuracy: 0.8567
# Validation Loss: 0.8999, Validation Accuracy: 0.6428
# Saved best model for fold 4 with validation accuracy: 0.6428
# Epoch 21/30, Loss: 0.3231, Accuracy: 0.8691
# Validation Loss: 0.8456, Validation Accuracy: 0.6292
# Epoch 22/30, Loss: 0.3222, Accuracy: 0.8648
# Validation Loss: 0.9295, Validation Accuracy: 0.6440
# Saved best model for fold 4 with validation accuracy: 0.6440
# Epoch 23/30, Loss: 0.3146, Accuracy: 0.8745
# Validation Loss: 0.9028, Validation Accuracy: 0.6020
# Epoch 24/30, Loss: 0.3056, Accuracy: 0.8762
# Validation Loss: 0.9577, Validation Accuracy: 0.6415
# Epoch 25/30, Loss: 0.3000, Accuracy: 0.8785
# Validation Loss: 0.9744, Validation Accuracy: 0.6428
# Epoch 26/30, Loss: 0.2905, Accuracy: 0.8792
# Validation Loss: 0.9742, Validation Accuracy: 0.6391
# Epoch 27/30, Loss: 0.2907, Accuracy: 0.8795
# Validation Loss: 1.0298, Validation Accuracy: 0.6477
# Saved best model for fold 4 with validation accuracy: 0.6477
# Epoch 28/30, Loss: 0.2799, Accuracy: 0.8862
# Validation Loss: 1.0137, Validation Accuracy: 0.6366
# Epoch 29/30, Loss: 0.2847, Accuracy: 0.8893
# Validation Loss: 1.0611, Validation Accuracy: 0.6440
# Epoch 30/30, Loss: 0.2734, Accuracy: 0.8869
# Validation Loss: 1.0689, Validation Accuracy: 0.6415
#
# Fold 5
# Epoch 1/30, Loss: 0.7037, Accuracy: 0.4801
# Validation Loss: 0.6614, Validation Accuracy: 0.7030
# Saved best model for fold 5 with validation accuracy: 0.7030
# Epoch 2/30, Loss: 0.7013, Accuracy: 0.4801
# Validation Loss: 0.6654, Validation Accuracy: 0.7030
# Epoch 3/30, Loss: 0.7000, Accuracy: 0.4801
# Validation Loss: 0.6693, Validation Accuracy: 0.7030
# Epoch 4/30, Loss: 0.6978, Accuracy: 0.4801
# Validation Loss: 0.6743, Validation Accuracy: 0.7030
# Epoch 5/30, Loss: 0.6957, Accuracy: 0.4801
# Validation Loss: 0.6798, Validation Accuracy: 0.7030
# Epoch 6/30, Loss: 0.6934, Accuracy: 0.4801
# Validation Loss: 0.6852, Validation Accuracy: 0.7030
# Epoch 7/30, Loss: 0.6900, Accuracy: 0.5110
# Validation Loss: 0.6901, Validation Accuracy: 0.5941
# Epoch 8/30, Loss: 0.6843, Accuracy: 0.7320
# Validation Loss: 0.6981, Validation Accuracy: 0.3978
# Epoch 9/30, Loss: 0.6739, Accuracy: 0.7304
# Validation Loss: 0.7053, Validation Accuracy: 0.4059
# Epoch 10/30, Loss: 0.6546, Accuracy: 0.7271
# Validation Loss: 0.7184, Validation Accuracy: 0.4220
# Epoch 11/30, Loss: 0.6198, Accuracy: 0.7284
# Validation Loss: 0.7234, Validation Accuracy: 0.4556
# Epoch 12/30, Loss: 0.5740, Accuracy: 0.7573
# Validation Loss: 0.7555, Validation Accuracy: 0.4651
# Epoch 13/30, Loss: 0.5268, Accuracy: 0.7737
# Validation Loss: 0.8018, Validation Accuracy: 0.4637
# Epoch 14/30, Loss: 0.4842, Accuracy: 0.7872
# Validation Loss: 0.8583, Validation Accuracy: 0.4583
# Epoch 15/30, Loss: 0.4491, Accuracy: 0.8072
# Validation Loss: 0.8933, Validation Accuracy: 0.4624
# Epoch 16/30, Loss: 0.4191, Accuracy: 0.8171
# Validation Loss: 0.9658, Validation Accuracy: 0.4624
# Epoch 17/30, Loss: 0.3916, Accuracy: 0.8292
# Validation Loss: 1.0524, Validation Accuracy: 0.4140
# Epoch 18/30, Loss: 0.3640, Accuracy: 0.8433
# Validation Loss: 1.0784, Validation Accuracy: 0.4449
# Epoch 19/30, Loss: 0.3519, Accuracy: 0.8562
# Validation Loss: 1.1914, Validation Accuracy: 0.4113
# Epoch 20/30, Loss: 0.3380, Accuracy: 0.8614
# Validation Loss: 1.0548, Validation Accuracy: 0.4624
# Epoch 21/30, Loss: 0.3188, Accuracy: 0.8686
# Validation Loss: 1.2601, Validation Accuracy: 0.4140
# Epoch 22/30, Loss: 0.3052, Accuracy: 0.8729
# Validation Loss: 1.2622, Validation Accuracy: 0.4167
# Epoch 23/30, Loss: 0.3059, Accuracy: 0.8808
# Validation Loss: 1.3805, Validation Accuracy: 0.4059
# Epoch 24/30, Loss: 0.2933, Accuracy: 0.8828
# Validation Loss: 1.4235, Validation Accuracy: 0.4194
# Epoch 25/30, Loss: 0.2768, Accuracy: 0.8903
# Validation Loss: 1.4449, Validation Accuracy: 0.4126
# Epoch 26/30, Loss: 0.2700, Accuracy: 0.8844
# Validation Loss: 1.4227, Validation Accuracy: 0.4301
# Epoch 27/30, Loss: 0.2626, Accuracy: 0.9031
# Validation Loss: 1.4551, Validation Accuracy: 0.4274
# Epoch 28/30, Loss: 0.2547, Accuracy: 0.9038
# Validation Loss: 1.4741, Validation Accuracy: 0.4167
# Epoch 29/30, Loss: 0.2544, Accuracy: 0.8969
# Validation Loss: 1.5356, Validation Accuracy: 0.4167
# Epoch 30/30, Loss: 0.2410, Accuracy: 0.9018
# Validation Loss: 1.6226, Validation Accuracy: 0.4073
# Average Validation Accuracy: 0.6957
# Best model from fold 1 with validation accuracy: 0.8123

# %%
scaler = StandardScaler()
test_features = scaler.fit_transform(test_data_array.reshape(-1, test_data_array.shape[-1])).reshape(test_data_array.shape)
test_features = torch.tensor(test_features, dtype=torch.float32).to(device)
test_labels = torch.tensor(test_label_array, dtype=torch.float32).unsqueeze(1).to(device)
test_dataset = TensorDataset(test_features, test_labels)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Evaluate the best model on test set
model = CNNModel(input_shape=test_features.shape).to(device)
model.load_state_dict(torch.load('/kaggle/working/best_model_fold_2.pth'))
model.eval()

all_preds = []
all_labels = []
all_probs = []
with torch.no_grad():
    for inputs, labels in test_loader:
        outputs = model(inputs)
        probs = outputs.cpu().numpy()
        predicted = (outputs >= 0.5).float()
        all_preds.extend(predicted.cpu().numpy().flatten())
        all_labels.extend(labels.cpu().numpy().flatten())
        all_probs.extend(probs.flatten())

# Calculate metrics
cm = confusion_matrix(all_labels, all_preds)
tn, fp, fn, tp = cm.ravel()
sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0.0
specificity = tn / (tn + fp) if (tn + fp) > 0 else 0.0
accuracy = (tp + tn) / (tp + tn + fp + fn) if (tp + tn + fp + fn) > 0 else 0.0
f1 = f1_score(all_labels, all_preds)
roc_auc = roc_auc_score(all_labels, all_probs)

print("\nTest Set Evaluation:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Sensitivity (Recall): {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"ROC-AUC: {roc_auc:.4f}")
print(f"Confusion Matrix:\n{cm}")
# Plot Confusion Matrix Heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['NORMAL', 'MCI'], yticklabels=['NORMAL', 'MCI'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.savefig('confusion_matrix.png')
plt.show()
plt.close()

# Plot ROC Curve
fpr, tpr, _ = roc_curve(all_labels, all_probs)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})', color='blue')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.savefig('roc_curve.png')
plt.show()
plt.close()
# Out:
# Test Set Evaluation:
# Accuracy: 0.6903
# Sensitivity (Recall): 0.6098
# Specificity: 0.7720
# F1-Score: 0.6647
# ROC-AUC: 0.6925
# Confusion Matrix:
# [[281  83]
#  [144 225]]

# %%
# Define function to compute Saliency Maps
import random
def compute_saliency_map(model, input_data, target_class, device):
    model.eval()
    input_data = input_data.unsqueeze(0).to(device).requires_grad_(True)  # Shape: (1, channels, length)

    # Forward pass
    output = model(input_data)
    model.zero_grad()

    # Backward pass to get gradients
    output.backward()  # For binary classification, backpropagate the single output

    # Get the gradients of the input
    saliency = input_data.grad.abs().squeeze(0).cpu().numpy()  # Shape: (channels, sequence_length)
    saliency = np.mean(saliency, axis=0)  # Average over channels to get a 1D saliency map
    return saliency

# Load the pre-trained model (adjust path accordingly)
model_path = "/kaggle/working/best_model_fold_2.pth"  # Thay bằng đường dẫn tới file trọng số đã lưu
model.load_state_dict(torch.load(model_path))
model.eval()

# Prepare test data for Saliency Maps
test_dataset = TensorDataset(torch.tensor(test_data_array, dtype=torch.float32), 
                             torch.tensor(test_label_array, dtype=torch.float32).unsqueeze(1))
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

flat_samples = [(x[0], x[1]) for x in list(test_loader)]
random_samples = random.sample(flat_samples, 5)
# Compute and visualize Saliency Maps
saliency_maps = []
all_preds = []
all_labels = []
all_probs = []

for i, (inputs, labels) in enumerate(random_samples):
    inputs, labels = inputs.to(device), labels.to(device)
    output = model(inputs)
    probs = output.detach().cpu().numpy().flatten()
    predicted = (output >= 0.5).float()
    all_preds.extend(predicted.cpu().numpy().flatten())
    all_labels.extend(labels.cpu().numpy().flatten())
    all_probs.extend(probs)

    # Compute Saliency Map
    saliency = compute_saliency_map(model, inputs.squeeze(0), int(labels.item()), device)
    saliency_maps.append((i, saliency))

    # Visualize Saliency Map
    plt.figure()
    plt.plot(saliency, label='Saliency Map', color='red')
    plt.plot(inputs.squeeze(0).cpu().numpy().mean(axis=0), label='Average EEG Signal', alpha=0.5)
    plt.title(f'Saliency Map for Sample {i} (Label: {int(labels.item())}, Pred: {int(predicted.item())})')
    plt.xlabel('Time Step')
    plt.ylabel('Importance / Signal Value')
    plt.legend()
    plt.savefig(f'saliency_map_sample_{i}.png')
    plt.show()

# Calculate metrics
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(all_labels, all_preds)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[1 0]
#  [1 3]]

# %%
import torch
import torch.nn.functional as F
import numpy as np

def compute_gradcam_1d(model, input_tensor, true_label, device, target_layer='conv5'):
    model.eval()
    input_tensor = input_tensor.unsqueeze(0).to(device).requires_grad_(True)

    # Hook để lưu feature map và gradient tại tầng conv5
    activation = {}
    gradients = {}

    def forward_hook(module, input, output):
        activation['value'] = output.detach()

    def backward_hook(module, grad_input, grad_output):
        gradients['value'] = grad_output[0].detach()

    # Đăng ký hook vào tầng conv5
    hook_f = getattr(model, target_layer).register_forward_hook(forward_hook)
    hook_b = getattr(model, target_layer).register_backward_hook(backward_hook)

    # Forward
    output = model(input_tensor)
    predicted = (output >= 0.5).float()
    # predicted.item()
    pred =   predicted.item()  # Lấy nhãn dự đoán (Pred)
    print(f"Label: {true_label}, Pred: {pred}")  # In ra Label và Pred

    model.zero_grad()

    # Backward cho lớp đích: dùng nhãn thật (true_label) hoặc predicted nếu bạn muốn saliency theo prediction
    output.backward()

    # Lấy feature map và gradient
    fmap = activation['value'][0]  # shape: (C, L)
    grads = gradients['value'][0]  # shape: (C, L)

    # Tính trọng số theo Global Average Pooling
    weights = grads.mean(dim=1)  # shape: (C)

    # Tính Grad-CAM
    gradcam = torch.sum(weights[:, None] * fmap, dim=0)  # shape: (L,)
    gradcam = F.relu(gradcam)

    # Chuẩn hóa về [0, 1]
    gradcam = gradcam.cpu().numpy()
    gradcam = (gradcam - gradcam.min()) / (gradcam.max() - gradcam.min() + 1e-8)

    # Gỡ hook
    hook_f.remove()
    hook_b.remove()

    return gradcam, int(pred)

# %%
test_dataset = TensorDataset(torch.tensor(test_data_array, dtype=torch.float32), 
                             torch.tensor(test_label_array, dtype=torch.float32).unsqueeze(1))
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

flat_samples = [(x[0], x[1]) for x in list(test_loader)]
random_samples = random.sample(flat_samples, 5)
model_path = "/kaggle/working/best_model_fold_2.pth"  # Thay bằng đường dẫn tới file trọng số đã lưu
model.load_state_dict(torch.load(model_path))
for i, (inputs, labels) in enumerate(random_samples):
    inputs, labels = inputs.to(device), labels.to(device)
    gradcam_map,pred = compute_gradcam_1d(model, inputs.squeeze(0), int(labels.item()), device)
    plt.figure()
    plt.plot(gradcam_map, label='Grad-CAM', color='orange')
    plt.plot(inputs.squeeze(0).cpu().numpy().mean(axis=0), label='Avg EEG Signal', alpha=0.5)
    plt.title(f'Grad-CAM for Sample {i} (Label: {int(labels.item())}) Pred: {pred}')
    plt.xlabel('Time Step')
    plt.ylabel('Importance / Signal Value')
    plt.legend()
    plt.savefig(f'gradcam_sample_{i}.png')
    plt.show()
    plt.close()
# Out:
# Label: 0, Pred: 1.0
# Label: 1, Pred: 0.0
# Label: 0, Pred: 0.0
# Label: 1, Pred: 1.0
# Label: 1, Pred: 0.0
